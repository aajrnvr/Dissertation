# %% [markdown]
# <a href="https://colab.research.google.com/github/aajrnvr/Dissertation/blob/main/experiments_results_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Preparation

import numpy as np
import pandas as pd

# %% [markdown]
# # **Readmission**

# %%
# Readmission-AUROC

# prompt_1: ManualTemplate + SoftVerbalizer
# prompt_2: MixedTemplate + ManualVerbalizer
# prompt_3: MixedTemplate + SoftVerbalizer
# prompt_4: ManualTemplate + KnowledgeableVerbalizer
# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# finetune


y_prompt_1 = np.array([0.538, 0.542, 0.553, 0.567, 0.582, 0.591]) # zero-shot, 8, 16, 32, 64, 128, 256
std_prompt_1 = np.array([0.025, 0.02, 0.019, 0.016, 0.014, 0.006])/2 

y_prompt_2 = np.array([0.541, 0.554, 0.569, 0.582, 0.598, 0.605])
std_prompt_2 = np.array([0.0255, 0.023, 0.020, 0.016, 0.013, 0.008])/2

y_prompt_3 = np.array([0.529, 0.544, 0.561, 0.582, 0.601, 0.618])
std_prompt_3 = np.array([0.025, 0.025, 0.012, 0.016, 0.013, 0.008])/2

y_prompt_4 = np.array([0.542, 0.561, 0.57, 0.593, 0.609, 0.631])
std_prompt_4 = np.array([0.025, 0.024, 0.020, 0.016, 0.012, 0.009])/2

y_prompt_5 = np.array([0.543, 0.569, 0.577, 0.5991, 0.615, 0.635])
std_prompt_5 = np.array([0.023, 0.025, 0.016, 0.016, 0.013, 0.0075])/2

y_finetune = np.array([0.521, 0.534, 0.559, 0.577, 0.599, 0.64]) 
std_finetune = np.array([0.027, 0.021, 0.017, 0.016, 0.015, 0.007])/2 

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))

plt.plot(x, y_prompt_1, label = 'ManualTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_2, label = 'MixedTemplate + ManualVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_3, label = 'MixedTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_4, label = 'ManualTemplate + KnowledgeableVerbalizer', color = 'black', marker = 'x')
plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')

x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)

plt.fill_between(x, (y_prompt_1-std_prompt_1), (y_prompt_1+std_prompt_1), alpha=0.1)
plt.fill_between(x, (y_prompt_2-std_prompt_2),(y_prompt_2+std_prompt_2), alpha = 0.1)
plt.fill_between(x, (y_prompt_3-std_prompt_3),(y_prompt_3+std_prompt_3), alpha = 0.1)
plt.fill_between(x, (y_prompt_4-std_prompt_4),(y_prompt_4+std_prompt_4), alpha = 0.15)
plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.15)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)


plt.ylabel('AUROC')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./readmission_auroc_plot.pdf', dpi=1000)

# %%
# Readmission-acc


# prompt_1: ManualTemplate + SoftVerbalizer
# prompt_2: MixedTemplate + ManualVerbalizer
# prompt_3: MixedTemplate + SoftVerbalizer
# prompt_4: ManualTemplate + KnowledgeableVerbalizer
# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# finetune


y_prompt_1 = np.array([0.536, 0.542, 0.554, 0.561, 0.577, 0.586]) # zero-shot, 8, 16, 32, 64, 128, 256
std_prompt_1 = np.array([0.015, 0.012, 0.011, 0.01, 0.008, 0.004])/2 

y_prompt_2 = np.array([0.537, 0.544, 0.553, 0.559, 0.578, 0.589])
std_prompt_2 = np.array([0.017, 0.013, 0.011, 0.01, 0.009, 0.004])/2

y_prompt_3 = np.array([0.536, 0.544, 0.557, 0.565, 0.581, 0.591])
std_prompt_3 = np.array([0.020, 0.019, 0.015, 0.014, 0.011, 0.006])/2

y_prompt_4 = np.array([0.541, 0.5503, 0.560, 0.573, 0.589, 0.599])
std_prompt_4 = np.array([0.02, 0.021, 0.016, 0.015, 0.01, 0.007])/2

y_prompt_5 = np.array([0.538, 0.549, 0.566, 0.578, 0.59, 0.605])
std_prompt_5 = np.array([0.02, 0.019, 0.013, 0.011, 0.01, 0.006])/2

y_finetune = np.array([0.531, 0.539, 0.551, 0.56, 0.57, 0.577]) 
std_finetune = np.array([0.022, 0.02, 0.017, 0.019, 0.014, 0.004])/2 

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))

plt.plot(x, y_prompt_1, label = 'ManualTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_2, label = 'MixedTemplate + ManualVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_3, label = 'MixedTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_4, label = 'ManualTemplate + KnowledgeableVerbalizer', color = 'black', marker = 'x')
plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')

x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)

plt.fill_between(x, (y_prompt_1-std_prompt_1), (y_prompt_1+std_prompt_1), alpha=0.1)
plt.fill_between(x, (y_prompt_2-std_prompt_2),(y_prompt_2+std_prompt_2), alpha = 0.1)
plt.fill_between(x, (y_prompt_3-std_prompt_3),(y_prompt_3+std_prompt_3), alpha = 0.1)
plt.fill_between(x, (y_prompt_4-std_prompt_4),(y_prompt_4+std_prompt_4), alpha = 0.15)
plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.15)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)


plt.ylabel('acc')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./readmission_acc_plot.pdf', dpi=1000)

# %% [markdown]
# #**Mortality**

# %%
# Mortality-AUROC


# prompt_1: ManualTemplate + SoftVerbalizer
# prompt_2: MixedTemplate + ManualVerbalizer
# prompt_3: MixedTemplate + SoftVerbalizer
# prompt_4: ManualTemplate + KnowledgeableVerbalizer
# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# finetune


y_prompt_1 = np.array([0.534, 0.543, 0.555, 0.569, 0.581, 0.59]) # zero-shot, 8, 16, 32, 64, 128, 256
std_prompt_1 = np.array([0.024, 0.02, 0.013, 0.016, 0.015, 0.006])/2 

y_prompt_2 = np.array([0.538, 0.544, 0.559, 0.572, 0.584, 0.592])
std_prompt_2 = np.array([0.0265, 0.023, 0.021, 0.016, 0.013, 0.008])/2

y_prompt_3 = np.array([0.539, 0.549, 0.565, 0.583, 0.601, 0.613])
std_prompt_3 = np.array([0.024, 0.025, 0.013, 0.016, 0.014, 0.008])/2

y_prompt_4 = np.array([0.549, 0.565, 0.57, 0.594, 0.609, 0.634])
std_prompt_4 = np.array([0.025, 0.022, 0.021, 0.017, 0.01, 0.006])/2

y_prompt_5 = np.array([0.546, 0.562, 0.577, 0.5994, 0.618, 0.637])
std_prompt_5 = np.array([0.021, 0.025, 0.013, 0.016, 0.014, 0.0076])/2

y_finetune = np.array([0.523, 0.531, 0.559, 0.581, 0.614, 0.652]) 
std_finetune = np.array([0.025, 0.02, 0.017, 0.017, 0.015, 0.007])/2 

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))

plt.plot(x, y_prompt_1, label = 'ManualTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_2, label = 'MixedTemplate + ManualVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_3, label = 'MixedTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_4, label = 'ManualTemplate + KnowledgeableVerbalizer', color = 'black', marker = 'x')
plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')

x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)

plt.fill_between(x, (y_prompt_1-std_prompt_1), (y_prompt_1+std_prompt_1), alpha=0.1)
plt.fill_between(x, (y_prompt_2-std_prompt_2),(y_prompt_2+std_prompt_2), alpha = 0.1)
plt.fill_between(x, (y_prompt_3-std_prompt_3),(y_prompt_3+std_prompt_3), alpha = 0.1)
plt.fill_between(x, (y_prompt_4-std_prompt_4),(y_prompt_4+std_prompt_4), alpha = 0.15)
plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.15)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)


plt.ylabel('AUROC')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./mortality_auroc_plot.pdf', dpi=1000)

# %%
# Mortality-acc

# prompt_1: ManualTemplate + SoftVerbalizer
# prompt_2: MixedTemplate + ManualVerbalizer
# prompt_3: MixedTemplate + SoftVerbalizer
# prompt_4: ManualTemplate + KnowledgeableVerbalizer
# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# finetune

y_prompt_1 = np.array([0.515, 0.533, 0.557, 0.566, 0.573, 0.58]) # zero-shot, 8, 16, 32, 64, 128, 256
std_prompt_1 = np.array([0.014, 0.012, 0.01, 0.013, 0.007, 0.004])/2 

y_prompt_2 = np.array([0.521, 0.537, 0.551, 0.562, 0.574, 0.589])
std_prompt_2 = np.array([0.014, 0.013, 0.013, 0.01, 0.006, 0.004])/2

y_prompt_3 = np.array([0.523, 0.541, 0.558, 0.565, 0.582, 0.591])
std_prompt_3 = np.array([0.021, 0.019, 0.015, 0.014, 0.011, 0.006])/2

y_prompt_4 = np.array([0.528, 0.546, 0.564, 0.574, 0.589, 0.601])
std_prompt_4 = np.array([0.02, 0.02, 0.016, 0.014, 0.01, 0.008])/2

y_prompt_5 = np.array([0.525, 0.543, 0.566, 0.581, 0.599, 0.605])
std_prompt_5 = np.array([0.021, 0.015, 0.013, 0.013, 0.01, 0.003])/2

y_finetune = np.array([0.521, 0.534, 0.543, 0.56, 0.57, 0.577]) 
std_finetune = np.array([0.02, 0.02, 0.017, 0.015, 0.015, 0.0052])/2 

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))

plt.plot(x, y_prompt_1, label = 'ManualTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_2, label = 'MixedTemplate + ManualVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_3, label = 'MixedTemplate + SoftVerbalizer', marker = 'x', alpha = 0.4)
plt.plot(x, y_prompt_4, label = 'ManualTemplate + KnowledgeableVerbalizer', color = 'black', marker = 'x')
plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')

x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)

plt.fill_between(x, (y_prompt_1-std_prompt_1), (y_prompt_1+std_prompt_1), alpha=0.1)
plt.fill_between(x, (y_prompt_2-std_prompt_2),(y_prompt_2+std_prompt_2), alpha = 0.1)
plt.fill_between(x, (y_prompt_3-std_prompt_3),(y_prompt_3+std_prompt_3), alpha = 0.1)
plt.fill_between(x, (y_prompt_4-std_prompt_4),(y_prompt_4+std_prompt_4), alpha = 0.12)
plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.12)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)


plt.ylabel('acc')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./mortality_acc_plot.pdf', dpi=1000)

# %% [markdown]
# # For Ablation study

# %% [markdown]
# ## Readmission

# %%
# Readmission-AUROC

# prompt_1: ManualTemplate + SoftVerbalizer
# prompt_2: MixedTemplate + ManualVerbalizer
# prompt_3: MixedTemplate + SoftVerbalizer
# prompt_4: ManualTemplate + KnowledgeableVerbalizer
# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# prompt_6: ManualTemplate + KnowledgeableVerbalizer (fixed weights)
# prompt_7: MixedTemplate + KnowledgeableVerbalizer (fixed weights)
# finetune



y_prompt_4 = np.array([0.542, 0.561, 0.57, 0.593, 0.609, 0.631])
std_prompt_4 = np.array([0.025, 0.024, 0.020, 0.016, 0.012, 0.009])/2

y_prompt_5 = np.array([0.543, 0.569, 0.577, 0.5991, 0.615, 0.635])
std_prompt_5 = np.array([0.023, 0.025, 0.016, 0.016, 0.013, 0.0075])/2

y_prompt_7 = np.array([0.536, 0.54, 0.553, 0.563, 0.567, 0.572])
std_prompt_7 = np.array([0.021, 0.024, 0.017, 0.015, 0.014, 0.0076])/2



y_finetune = np.array([0.521, 0.534, 0.559, 0.577, 0.599, 0.64]) 
std_finetune = np.array([0.027, 0.021, 0.017, 0.016, 0.015, 0.007]) 

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))


# plt.plot(x, y_prompt_4, label = 'ManualTemplate + KnowledgeableVerbalizer', color = 'black', marker = 'x')
plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_prompt_7, label = 'MixedTemplate + KnowledgeableVerbalizer (fixed weights)', color = 'black',marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')


x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)


# plt.fill_between(x, (y_prompt_4-std_prompt_4),(y_prompt_4+std_prompt_4), alpha = 0.15)
plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.15)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)
plt.fill_between(x, (y_prompt_7-std_prompt_7), (y_prompt_7+std_prompt_7), alpha = 0.1)


plt.ylabel('AUROC')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./ablation_readmission_auroc_plot.pdf', dpi=1000)

# %%
# Readmission-acc


# prompt_1: ManualTemplate + SoftVerbalizer
# prompt_2: MixedTemplate + ManualVerbalizer
# prompt_3: MixedTemplate + SoftVerbalizer
# prompt_4: ManualTemplate + KnowledgeableVerbalizer
# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# prompt_6: ManualTemplate + KnowledgeableVerbalizer (fixed weights)
# prompt_7: MixedTemplate + KnowledgeableVerbalizer (fixed weights)
# finetune



y_prompt_5 = np.array([0.538, 0.549, 0.566, 0.578, 0.59, 0.605])
std_prompt_5 = np.array([0.017, 0.015, 0.013, 0.011, 0.0075, 0.006])/2

y_prompt_7 = np.array([0.534, 0.542, 0.5481, 0.556, 0.553, 0.56])
std_prompt_7 = np.array([0.012, 0.013, 0.012, 0.011, 0.009, 0.008])/2

y_finetune = np.array([0.531, 0.539, 0.551, 0.56, 0.57, 0.577]) 
std_finetune = np.array([0.021, 0.019, 0.016, 0.014, 0.010, 0.0035])/2

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))


plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_prompt_7, label = 'MixedTemplate + KnowledgeableVerbalizer (fixed weights)', color = 'black', marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')

x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)

plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.15)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)
plt.fill_between(x, (y_prompt_7-std_prompt_7), (y_prompt_7+std_prompt_7), alpha = 0.1)

plt.ylabel('acc')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./ablation_readmission_acc_plot.pdf', dpi=1000)

# %% [markdown]
# ## Mortality

# %%
# Mortality-AUROC



# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# prompt_7: MixedTemplate + KnowledgeableVerbalizer (fixed weights)
# finetune



y_prompt_5 = np.array([0.546, 0.562, 0.577, 0.5994, 0.618, 0.637])
std_prompt_5 = np.array([0.021, 0.025, 0.013, 0.016, 0.014, 0.0076])/2

y_prompt_7 = np.array([0.535, 0.543, 0.561, 0.579, 0.583, 0.594])
std_prompt_7 = np.array([0.02, 0.023, 0.014, 0.015, 0.013, 0.0086])/2

y_finetune = np.array([0.523, 0.531, 0.559, 0.581, 0.614, 0.652]) 
std_finetune = np.array([0.025, 0.02, 0.017, 0.017, 0.015, 0.007])/2 

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))


plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_prompt_7, label = 'MixedTemplate + KnowledgeableVerbalizer (fixed weights)', color = 'black', marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')

x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)


plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.15)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)
plt.fill_between(x, (y_prompt_7-std_prompt_7),(y_prompt_7+std_prompt_7),alpha = 0.1)


plt.ylabel('AUROC')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./ablation_mortality_auroc_plot.pdf', dpi=1000)

# %%
# Mortality-acc


# prompt_5: MixedTemplate + KnowledgeableVerbalizer
# prompt_7: MixedTemplate + KnowledgeableVerbalizer (fixed weights)
# finetune



y_prompt_5 = np.array([0.525, 0.543, 0.566, 0.581, 0.599, 0.605])
std_prompt_5 = np.array([0.021, 0.015, 0.013, 0.013, 0.01, 0.003])/2

y_prompt_7 = np.array([0.522, 0.54, 0.543, 0.552, 0.573, 0.574])
std_prompt_7 = np.array([0.022, 0.014, 0.012, 0.011, 0.009, 0.004])/2

y_finetune = np.array([0.521, 0.534, 0.543, 0.56, 0.57, 0.577]) 
std_finetune = np.array([0.02, 0.02, 0.017, 0.015, 0.015, 0.0052])/2 

from matplotlib import pyplot as plt
import numpy as np


x = np.arange(y_prompt_1.shape[0])

plt.figure(figsize=(8,8))

plt.plot(x, y_prompt_5, label = 'MixedTemplate + KnowledgeableVerbalizer', color = 'red', marker = 'x')
plt.plot(x, y_prompt_7, label = 'MixedTemplate + KnowledgeableVerbalizer (fixed weights)', color = 'black', marker = 'x')
plt.plot(x, y_finetune, label = 'finetune', color = 'blue',marker = 'o')


x_ticks = [8, 16, 32, 64, 128, 256]
plt.xticks(x, x_ticks)

plt.fill_between(x, (y_prompt_5-std_prompt_5),(y_prompt_5+std_prompt_5), alpha = 0.12)
plt.fill_between(x, (y_finetune-std_finetune), (y_finetune+std_finetune), alpha=0.1)
plt.fill_between(x, (y_prompt_7-std_prompt_7),(y_prompt_7+std_prompt_7), alpha = 0.1)

plt.ylabel('acc')
plt.xlabel('number of examples per label')

plt.legend()
plt.savefig('./ablation_mortality_acc_plot.pdf', dpi=1000)
